# %%
import pandas as pd 
import numpy as np

# %%
中央政治局常务委员会委员 = ['习近平','李克强','栗战书','汪洋','王沪宁','赵乐际','韩正']

# %%
中央政治局委员 = ['习近平','李克强','栗战书','汪洋','王沪宁','赵乐际','韩正','丁薛祥','王晨','刘鹤','许其亮','孙春兰','李希','李强','李鸿忠','杨洁篪','杨晓渡','张又侠','陈希','陈全国','陈敏尔','胡春华','郭声琨','黄坤明','蔡奇']

# %%
中央书记处书记 = ['王沪宁','丁薛祥','杨晓渡','陈希','郭声琨','黄坤明','尤权']

# %%
army = ['习近平','许其亮','张又侠']

# %%
person_dict = {'国家主席':'习近平',
        '国家副主席':'王岐山',
       '人大常务委员长':'栗战书',
       '国务院总理':'李克强',
       '国务院副总理':'韩正',
        '国务院副总理':'孙春兰',
        '国务院副总理':'刘鹤',
        '国务院副总理':'胡春华',
        '国防部长':'魏凤和',
        '外交部长':'王毅',
        '国务院秘书长':'肖捷',
        '公安部长':'赵克志',
        '军委副主席':'许其亮',
        '军委副主席':'张又侠',
        '监察委':'杨晓渡',
        '最高人民法院':'周强',
        '最高检察院':'张军',
        '政协':'汪洋',
        '中纪委':'赵乐际',
        '中组部':'陈希'          
       }

# %%
province = {'中国': '',
 '北京': '华北',
 '上海': '华东',
 '天津': '华北',
 '重庆': '西南',
 '河北': '华北',
 '山西': '华北',
 '河南': '华中',
 '辽宁': '东北',
 '吉林': '东北',
 '黑龙江': '东北',
 '内蒙古': '华北',
 '江苏': '华东',
 '山东': '华东',
 '安徽': '华东',
 '浙江': '华东',
 '福建': '华东',
 '钓鱼岛': '华南',
 '湖北': '华中',
 '湖南': '华中',
 '广东': '华南',
 '广西': '华南',
 '江西': '华东',
 '四川': '西南',
 '海南': '华南',
 '贵州': '西南',
 '云南': '西南',
 '陕西': '西北',
 '甘肃': '西北',
 '青海': '西北',
 '宁夏': '西北',
 '新疆': '西北',
 '香港': '华南',
 '台湾': '华东',
 '澳门': '华南',
 '西藏': '西南',
 '港澳': '华南'}

# %%
name = province.keys()
name
# Out:
# dict_keys(['中国', '北京', '上海', '天津', '重庆', '河北', '山西', '河南', '辽宁', '吉林', '黑龙江', '内蒙古', '江苏', '山东', '安徽', '浙江', '福建', '钓鱼岛', '湖北', '湖南', '广东', '广西', '江西', '四川', '海南', '贵州', '云南', '陕西', '甘肃', '青海', '宁夏', '新疆', '香港', '台湾', '澳门', '西藏', '港澳'])

# %%
抽象词 = ['经济','高质量发展','贫困','covid','创新','发展','改革','畅通','市场活力','企业','行业','产业','区域']

# %%
产品 = ['农产品', '新能源','国货','家电','旅游','文化','体育','家居','人工智能']

# %%
# list与dict互转

def dict_tran(input_list):
    keys = input_list
    value =[0*i for i in range(len(keys))]
    d = dict(zip(keys,value))
    return d

# %%
a = dict_tran(name)

# %%
a
# Out:
# {'中国': 0,
#  '北京': 0,
#  '上海': 0,
#  '天津': 0,
#  '重庆': 0,
#  '河北': 0,
#  '山西': 0,
#  '河南': 0,
#  '辽宁': 0,
#  '吉林': 0,
#  '黑龙江': 0,
#  '内蒙古': 0,
#  '江苏': 0,
#  '山东': 0,
#  '安徽': 0,
#  '浙江': 0,
#  '福建': 0,
#  '钓鱼岛': 0,
#  '湖北': 0,
#  '湖南': 0,
#  '广东': 0,
#  '广西': 0,
#  '江西': 0,
#  '四川': 0,
#  '海南': 0,
#  '贵州': 0,
#  '云南': 0,
#  '陕西': 0,
#  '甘肃': 0,
#  '青海': 0,
#  '宁夏': 0,
#  '新疆': 0,
#  '香港': 0,
#  '台湾': 0,
#  '澳门': 0,
#  '西藏': 0,
#  '港澳': 0}

# %%
stock_industry = ['IT设备',
 '专用机械',
 '中成药',
 '乳制品',
 '互联网',
 '仓储物流',
 '供气供热',
 '保险',
 '元器件',
 '全国地产',
 '公共交通',
 '公路',
 '其他商业',
 '其他建材',
 '农业综合',
 '农用机械',
 '农药化肥',
 '出版业',
 '化学制药',
 '化工原料',
 '化工机械',
 '化纤',
 '区域地产',
 '医疗保健',
 '医药商业',
 '半导体',
 '商品城',
 '商贸代理',
 '啤酒',
 '园区开发',
 '塑料',
 '多元金融',
 '家居用品',
 '家用电器',
 '小金属',
 '工程机械',
 '广告包装',
 '建筑工程',
 '影视音像',
 '房产服务',
 '批发业',
 '摩托车',
 '文教休闲',
 '新型电力',
 '旅游景点',
 '旅游服务',
 '日用化工',
 '普钢',
 '服饰',
 '机场',
 '机床制造',
 '机械基件',
 '林业',
 '染料涂料',
 '橡胶',
 '水力发电',
 '水务',
 '水泥',
 '水运',
 '汽车整车',
 '汽车服务',
 '汽车配件',
 '渔业',
 '港口',
 '火力发电',
 '焦炭加工',
 '煤炭开采',
 '特种钢',
 '环境保护',
 '玻璃',
 '生物制药',
 '电信运营',
 '电器仪表',
 '电器连锁',
 '电气设备',
 '白酒',
 '百货',
 '石油加工',
 '石油开采',
 '石油贸易',
 '矿物制品',
 '种植业',
 '空运',
 '红黄酒',
 '纺织',
 '纺织机械',
 '综合类',
 '航空',
 '船舶',
 '装修装饰',
 '证券',
 '超市连锁',
 '路桥',
 '软件服务',
 '软饮料',
 '轻工机械',
 '运输设备',
 '通信设备',
 '造纸',
 '酒店餐饮',
 '钢加工',
 '铁路',
 '铅锌',
 '铜',
 '铝',
 '银行',
 '陶瓷',
 '食品',
 '饲料',
 '黄金']

# %%
stock_dict = dict_tran(stock_industry)

# %%
stock_dict
# Out:
# {'IT设备': 0,
#  '专用机械': 0,
#  '中成药': 0,
#  '乳制品': 0,
#  '互联网': 0,
#  '仓储物流': 0,
#  '供气供热': 0,
#  '保险': 0,
#  '元器件': 0,
#  '全国地产': 0,
#  '公共交通': 0,
#  '公路': 0,
#  '其他商业': 0,
#  '其他建材': 0,
#  '农业综合': 0,
#  '农用机械': 0,
#  '农药化肥': 0,
#  '出版业': 0,
#  '化学制药': 0,
#  '化工原料': 0,
#  '化工机械': 0,
#  '化纤': 0,
#  '区域地产': 0,
#  '医疗保健': 0,
#  '医药商业': 0,
#  '半导体': 0,
#  '商品城': 0,
#  '商贸代理': 0,
#  '啤酒': 0,
#  '园区开发': 0,
#  '塑料': 0,
#  '多元金融': 0,
#  '家居用品': 0,
#  '家用电器': 0,
#  '小金属': 0,
#  '工程机械': 0,
#  '广告包装': 0,
#  '建筑工程': 0,
#  '影视音像': 0,
#  '房产服务': 0,
#  '批发业': 0,
#  '摩托车': 0,
#  '文教休闲': 0,
#  '新型电力': 0,
#  '旅游景点': 0,
#  '旅游服务': 0,
#  '日用化工': 0,
#  '普钢': 0,
#  '服饰': 0,
#  '机场': 0,
#  '机床制造': 0,
#  '机械基件': 0,
#  '林业': 0,
#  '染料涂料': 0,
#  '橡胶': 0,
#  '水力发电': 0,
#  '水务': 0,
#  '水泥': 0,
#  '水运': 0,
#  '汽车整车': 0,
#  '汽车服务': 0,
#  '汽车配件': 0,
#  '渔业': 0,
#  '港口': 0,
#  '火力发电': 0,
#  '焦炭加工': 0,
#  '煤炭开采': 0,
#  '特种钢': 0,
#  '环境保护': 0,
#  '玻璃': 0,
#  '生物制药': 0,
#  '电信运营': 0,
#  '电器仪表': 0,
#  '电器连锁': 0,
# ...

# %%
stock_key = ['IT',
 '机械',
 '中药',
 '乳业',
 '互联网',
 '物流',
 '供气供热',
 '保险',
 '元器件',
 '地产',
 '交通',
 '公路',
 '商业',
 '建材',
 '农业',
 '农业',
 '农业',
 '出版业',
 '医药',
 '化工',
 '化工',
 '化纤',
 '地产',
 '医疗',
 '医药',
 '半导体',
 '商品城',
 '商贸',
 '酒',
 '园区开发',
 '塑料',
 '金融',
 '家居',
 '电器',
 '小金属',
 '机械',
 '广告',
 '建筑',
 '影像',
 '房产',
 '批发业',
 '车',
 '文化',
 '电力',
 '旅游',
 '旅游',
 '化工',
 '普钢',
 '服饰',
 '机场',
 '制造',
 '机械',
 '林业',
 '染料',
 '橡胶',
 '水',
 '水',
 '水泥',
 '水',
 '汽车',
 '汽车',
 '汽车',
 '渔业',
 '港口',
 '发电',
 '焦炭',
 '煤炭',
 '钢',
 '环境保护',
 '玻璃',
 '医药',
 '电信',
 '电器',
 '电器',
 '电气',
 '酒',
 '百货',
 '石油',
 '石油',
 '石油',
 '矿',
 '种植',
 '空运',
 '酒',
 '纺织',
 '纺织',
 '综合类',
 '航空',
 '船舶',
 '装修',
 '证券',
 '超市',
 '路桥',
 '软件',
 '饮料',
 '轻工',
 '运输',
 '通信',
 '造纸',
 '餐饮',
 '钢',
 '铁路',
 '铅锌',
 '铜',
 '铝',
 '银行',
 '陶瓷',
 '食品',
 '饲料',
 '黄金']

# %%
stock_dict_key = dict(zip(stock_industry,stock_key))

# %%
stock_key_dict = dict_tran(stock_key)

# %%
stock_key_dict
# Out:
# {'IT': 0,
#  '机械': 0,
#  '中药': 0,
#  '乳业': 0,
#  '互联网': 0,
#  '物流': 0,
#  '供气供热': 0,
#  '保险': 0,
#  '元器件': 0,
#  '地产': 0,
#  '交通': 0,
#  '公路': 0,
#  '商业': 0,
#  '建材': 0,
#  '农业': 0,
#  '出版业': 0,
#  '医药': 0,
#  '化工': 0,
#  '化纤': 0,
#  '医疗': 0,
#  '半导体': 0,
#  '商品城': 0,
#  '商贸': 0,
#  '酒': 0,
#  '园区开发': 0,
#  '塑料': 0,
#  '金融': 0,
#  '家居': 0,
#  '电器': 0,
#  '小金属': 0,
#  '广告': 0,
#  '建筑': 0,
#  '影像': 0,
#  '房产': 0,
#  '批发业': 0,
#  '车': 0,
#  '文化': 0,
#  '电力': 0,
#  '旅游': 0,
#  '普钢': 0,
#  '服饰': 0,
#  '机场': 0,
#  '制造': 0,
#  '林业': 0,
#  '染料': 0,
#  '橡胶': 0,
#  '水': 0,
#  '水泥': 0,
#  '汽车': 0,
#  '渔业': 0,
#  '港口': 0,
#  '发电': 0,
#  '焦炭': 0,
#  '煤炭': 0,
#  '钢': 0,
#  '环境保护': 0,
#  '玻璃': 0,
#  '电信': 0,
#  '电气': 0,
#  '百货': 0,
#  '石油': 0,
#  '矿': 0,
#  '种植': 0,
#  '空运': 0,
#  '纺织': 0,
#  '综合类': 0,
#  '航空': 0,
#  '船舶': 0,
#  '装修': 0,
#  '证券': 0,
#  '超市': 0,
#  '路桥': 0,
#  '软件': 0,
#  '饮料': 0,
#  '轻工': 0,
#  '运输': 0,
#  '通信': 0,
#  '造纸': 0,
#  '餐饮': 0,
#  '铁路': 0,
#  '铅锌': 0,
#  '铜': 0,
# ...

# %%
# Out:
# 110
